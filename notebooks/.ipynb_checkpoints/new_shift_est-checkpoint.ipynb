# %%
import new_adventure as na
import new_adventure.derivative_free_estimation as dfe
import numpy as np
import matplotlib.pyplot as plt
import time
from jax import random as jrandom
import jax.numpy as jnp
import jax 
import pandas as pd
from tqdm import tqdm 

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ws = np.array([[1], [1]])
bs = [-1, 1]
barrier = na.Barriers.LogPolytopeBarrier(ws, bs)
se_barrier = na.Functions.ShiftEstimation(barrier, 0.001, np.eye(1), 500)
res = []
res1 = []
res1_ipm_e = []
res2 = []
res2_se = []
res2_ipm_e = []
upper_bound = 5
lower_bound = -5
num_lin_samples = 100
for x in np.linspace(lower_bound, upper_bound, num_lin_samples):
    res.append(barrier.f(np.array([[x]])))
#     res1.append(barrier.f1(np.array([[x]])))
#     res1_ipm_e.append(beta_first_shift_estimator(barrier, np.array([x]), np.abs(x), 5, 100))
    
#     res2.append(barrier.f2(np.array([[x]])))
#     res2_ipm_e.append(beta_second_shift_estimator(barrier, np.array([x]), np.abs(x), 10, 500))
#     res2_se.append(se_barrier.f2(np.array([[x]])))

# %%
plt.plot(np.linspace(lower_bound, upper_bound, num_lin_samples), res)
plt.show()
# plt.plot(np.linspace(lower_bound, upper_bound, num_lin_samples), np.array(res1)[:, 0, 0],)
# plt.plot(np.linspace(lower_bound, upper_bound, num_lin_samples), np.array(res1_ipm_e)[:],)

# plt.show()

# plt.plot(np.linspace(lower_bound, upper_bound, num_lin_samples), np.array(res1)[:, 0, 0],)
# plt.show()

# plt.plot(np.linspace(lower_bound, upper_bound, num_lin_samples), np.array(res2)[:, 0, 0, 0])
# # plt.show()
# plt.plot(np.linspace(lower_bound, upper_bound, num_lin_samples), np.array(res2_ipm_e)[:])
# plt.plot(np.linspace(lower_bound, upper_bound, num_lin_samples), np.array(res2_se)[:, 0, 0, 0])

# %%
errs = []
a = []
b = []
for x in np.linspace(-1, 1, 100):
    xs = np.array([[0, x]])
    est = beta_first_shift_estimator(barrier, xs[0], 200, 200, control_variate=True)
    true_grad = barrier.f1(xs)
    errs.append(np.linalg.norm(est - true_grad))
    a.append(est[1])
    b.append(true_grad[0][1])
plt.plot(np.linspace(-1, 1, 100), errs)
plt.show()
plt.plot(a)
plt.show()
plt.plot(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4abe4598df0b> in <module>
#       4 for x in np.linspace(-1, 1, 100):
#       5     xs = np.array([[0, x]])
# ----> 6     est = beta_first_shift_estimator(barrier, xs[0], 200, 200, control_variate=True)
#       7     true_grad = barrier.f1(xs)
#       8     errs.append(np.linalg.norm(est - true_grad))
#
# NameError: name 'beta_first_shift_estimator' is not defined

# %%
errs = []
a = []
b = []
for x in np.linspace(-0.32, -0.2, 100):
    xs = np.array([[0, x]])
    est_hess = beta_second_shift_estimator(barrier, xs[0], 5, 2000, control_variate=True)
    true_hess = barrier.f2(xs)
    
#     print(est_hess)
#     print(true_hess)
    
    est_inv_hess = np.linalg.inv(est_hess)
    true_inv_hess = np.linalg.inv(true_hess)
#     print(est_inv_hess)
#     print(true_inv_hess)
    
    errs.append(np.linalg.norm(est_hess - true_hess)/np.linalg.norm(true_hess))
    a.append(est_hess[0][0])
    b.append(true_hess[0][0][0])
plt.plot(np.linspace(-0.32, -0.2, 100), errs)
plt.show()
plt.plot(a)
plt.show()
plt.plot(b)

# %% [markdown]
# # High Dimensional

# %%
def test_multilevel(F, x_0, alpha, N, d_prime, jrandom_key):
    """Return C_inv, W, V for woodbury"""
    d = len(x_0)
    jrandom_key, subkey = jrandom.split(jrandom_key)
    sample_points, jrandom_key = dfe.jax_hit_run(x_0, F, x_0.shape[0], N, alpha, subkey)   
    out_grads = F.f1(sample_points)
    grad_X = dfe.new_proper_cov(sample_points, out_grads)
    
    XXt = dfe.np_new_cov(sample_points)
    
    curr_m = None
    
    for _ in range(100):
        jrandom_key, subkey = jrandom.split(jrandom_key)
        U_idxs = jrandom.choice(subkey, a=d_prime, shape=(d_prime,), replace=False)
        print(U_idxs)
        U = jnp.eye(d)[U_idxs].T
        C_inv = U.T.dot(XXt).dot(U)
        W = grad_X.dot(XXt).dot(U)
        V = U.T.dot(XXt)
        update_m = W.dot(jnp.linalg.inv(C_inv)).dot(V)
        if curr_m is None:
            curr_m = update_m
        else:
            curr_m += update_m    
            
    curr_m = curr_m / 100.
    print()
    return jnp.linalg.inv(curr_m)

# %%
np.random.seed(10)
dim = 1
num_barriers = dim * 2
dirs = np.random.normal(size=(num_barriers, dim)) # sample gaussian and normalize 
ws = dirs/np.linalg.norm(dirs, axis=1).reshape(-1, 1)
bs = np.ones(num_barriers)

jrandom_key = jrandom.PRNGKey(0)

xs = np.ones(dim) / np.linalg.norm(np.ones(dim))

# num_barriers = 6
# dim = 3
# dirs = np.random.normal(size=(num_barriers, dim)) # sample gaussian and normalize 
# ws = dirs/np.linalg.norm(dirs, axis=1).reshape(-1, 1)
# bs = np.ones(num_barriers)

barrier = na.Barriers.LogPolytopeBarrier(ws, bs)

F = na.Functions.Linear(np.ones(dim))

F = barrier # na.Functions.LinearCombination(F, barrier, [1, 1])

# %%
import numpy as np
from scipy.optimize import approx_fprime


def finite_difference_hessian(F, X, h):
    hess = []
    all_out_central = F.f(X)
    for i, x in enumerate(X):
        x_back = x - jnp.eye(x.shape[0]) * h
        x_forward = x + jnp.eye(x.shape[0]) * h
        
        out_back = F.f(x_back)
        out_forward = F.f(x_forward)
        
        curr_hess = jnp.diag((out_back + out_forward - 2 * all_out_central[i]) / h**2) 
        out_back = F.f(x_back)
        out_forward = F.f(x_forward)
        
        for d in range(1, len(x)):
        
            x_forward_forward = x + jnp.eye(x.shape[0]) * h + jnp.eye(x.shape[0], k=d) * h
            x_forward_backward = x + jnp.eye(x.shape[0]) * h - jnp.eye(x.shape[0], k=d) * h
            x_backward_forward = x - jnp.eye(x.shape[0]) * h + jnp.eye(x.shape[0], k=d) * h
            x_backward_backward = x - jnp.eye(x.shape[0]) * h - jnp.eye(x.shape[0], k=d) * h
  
            out_forward_forward = F.f(x_forward_forward)
            out_forward_backward = F.f(x_forward_backward)
            out_backward_forward = F.f(x_backward_forward)
            out_backward_backward = F.f(x_backward_backward)
            
            curr_off_diag = jnp.eye(x.shape[0], k=d) * (out_forward_forward - out_forward_backward - out_backward_forward + out_backward_backward).reshape(-1, 1)/(4.*h**2)
            curr_hess += curr_off_diag + curr_off_diag.T
            
        hess.append(curr_hess)
        
    return jnp.array(hess)

# %%
def second_beta_smoothing(F, x_0, N, alpha, jrandom_key):
    jrandom_key, subkey = jrandom.split(jrandom_key)
    sample_points, radius = dfe.jax_hit_run(x_0, F, 1, N, alpha - 2, subkey)

    out_points = F.f(sample_points)
    diff = sample_points - x_0

    est = diff.T.dot(out_points.reshape(-1, 1) * diff)

    return 1/float(N) * (2*alpha - 3)*(2*alpha - 1)/(2*(alpha-2)*radius**4) * (est*(2*alpha - 3) - radius**2 * jnp.sum(out_points))

def old_second_beta_smoothing(F, x_0, N, alpha, jrandom_key):
    jrandom_key, subkey = jrandom.split(jrandom_key)
    sample_points, radius = dfe.jax_hit_run(x_0, F, 1, N, alpha-2, subkey)

    out_points = F.f(sample_points)
#     print("mean old new", jnp.mean(sample_points))
    diff = sample_points - x_0

    est = diff.T.dot(out_points.reshape(-1, 1) * diff)
    
    return 2*(-1 + 2*alpha)*(est * (2*alpha - 3) - radius**2 * jnp.sum(out_points))/(3*radius**4) / float(N)
    
xs = jnp.array([0.9])

res = {"smoothing":{}, "simple_zeroth":{}, "multi_zeroth": {}, "first": {}}
jitted_old_beta = jax.jit(lambda alpha, N, subkey: dfe.beta_second_shift_estimator(F, alpha, N, subkey))
jitted_multi_beta = jax.jit(lambda alpha, N, subkey: dfe.new_beta_second_shift_estimator(F, alpha, N, subkey))
for alpha in tqdm(range(5, 150, 50)):
    for N in range(100, 5000, 500):
        print(N)
        for k in res:
            res[k][(alpha, N)] = []
        for _ in range(100):
            jrandom_key, subkey = jrandom.split(jrandom_key)
    #         a = second_beta_smoothing(F, xs, 1000, alpha, subkey)[0][0]
    #         b = old_second_beta_smoothing(F, xs, 1000, alpha, subkey)[0][0]

            # print(F.f2(xs.reshape(1, 1)))
            d = jitted_multi_beta(xs, alpha, N, subkey)[0][0]

#             c = jitted_old_beta(xs, alpha, N, subkey)[0][0]

    #         res["smoothing"][-1].append(a)
    #         res["simple_zeroth"][-1].append(b)
            res["multi_zeroth"][(alpha, N)].append(c)
            res["first"][(alpha, N)].append(d)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100
# Traced<ShapedArray(int32[], weak_type=True)>with<DynamicJaxprTrace(level=0/1)>
# ---------------------------------------------------------------------------
# UnfilteredStackTrace                      Traceback (most recent call last)
# <ipython-input-571-433fb4a27482> in <module>
#      39             # print(F.f2(xs.reshape(1, 1)))
# ---> 40             d = jitted_multi_beta(xs, alpha, N, subkey)[0][0]
#      41
#
# ~/miniconda3/lib/python3.6/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     142     try:
# --> 143       return fun(*args, **kwargs)
#     144     except Exception as e:
#
# ~/miniconda3/lib/python3.6/site-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     431         name=flat_fun.__name__,
# --> 432         donated_invars=donated_invars)
#     433     out_pytree_def = out_tree()
#
# ...

# %%
for k in res:
    plt.scatter(np.array([len(res[k][a]) * [a*10 + 5] for a in range(len(res[k]))]).reshape(-1), np.array(res[k]).reshape(-1), label=k)
plt.legend()
plt.ylim(-200, 600)
plt.show()

# %%
radius = 0.1
alpha = 9
print("A", (3*radius**4)/(3 - 8*alpha + 4 * alpha**2))
print("cov", (radius**2)/(2*alpha - 3))
# Out:
# A 1.1764705882352942e-06
# cov 0.0006666666666666668

# %%
2*(alpha-2)

# %%
xs[0] = 0.2
fd_hess = finite_difference_hessian(F, xs.reshape(1, -1), h=0.001)
print(fd_hess)
print()
print(F.f2(np.array([xs])))
# print(np.linalg.norm(fd_hess - true_hess)/np.linalg.norm(true_hess))
# Out:
# [[[ 4.2915344   0.44703484 -0.11920929 ...  0.44703484  0.08940697
#     0.4172325 ]
#   [ 0.44703484  6.198883   -0.11920929 ...  0.14901161 -0.5364418
#    -0.6556511 ]
#   [-0.11920929 -0.11920929  5.2452087  ... -0.29802322  0.23841858
#     0.02980232]
#   ...
#   [ 0.44703484  0.14901161 -0.29802322 ...  5.722046    0.20861626
#    -0.23841858]
#   [ 0.08940697 -0.5364418   0.23841858 ...  0.20861626  2.861023
#     0.11920929]
#   [ 0.4172325  -0.6556511   0.02980232 ... -0.23841858  0.11920929
#     2.3841858 ]]]
#
# [[[ 3.608017    0.09385373  0.18915385 ...  0.32568043  0.06292099
#    -0.05244399]
#   [ 0.09385374  3.5001607  -0.21355516 ...  0.02917045 -0.01353911
#     0.02522322]
#   [ 0.18915384 -0.21355519  4.0579786  ...  0.28902096  0.16122644
#     0.18406898]
#   ...
#   [ 0.3256804   0.02917044  0.28902096 ...  3.9180555   0.1903763
#    -0.04854035]
#   [ 0.06292097 -0.01353909  0.1612264  ...  0.19037628  3.922769
#     0.09233661]
# ...

# %%
jnp.array([1, 2]).reshape(-1, 1) - jnp.array([2, 3])
# Out:
# DeviceArray([[-1, -2],
#              [ 0, -1]], dtype=int32)

# %%
a = jnp.array([1, 2])
a + jnp.eye(2)*2
# Out:
# DeviceArray([[3., 2.],
#              [1., 4.]], dtype=float32)

# %%
sample_points, jrandom_key = dfe.jax_hit_run(xs, F, xs.shape[0], 10, 1000, jrandom_key)

c = F.f1(xs.reshape(1, -1))[0]

diffs = sample_points - xs # N, d

grads_inners = F.f1(xs.reshape(1, -1))[0].dot(diffs.T) # N

print(grads_inners.shape)

a = diffs.T.dot(diffs * grads_inners.reshape(-1, 1)) / len(diffs)
print(jnp.linalg.norm(a))
# Out:
# (10,)
# 0.0007141472

# %%
xs[0] = 0

true_hess = F.f2(np.array([xs]))
est_hess = dfe.new_beta_second_shift_estimator(F, xs, 5, 1000, jrandom_key) # 
est_zeroth_hess = dfe.beta_second_shift_estimator(F, xs, 1000, 1000, jrandom_key)
print(np.diag(est_zeroth_hess))
est_zeroth_hess = dfe.beta_second_shift_estimator(F, xs, 10, 1000, jrandom_key)

idx = 7
print("zeroth", jnp.diag(est_zeroth_hess))
# print("first", est_hess)
print("true", jnp.diag(true_hess[0]))
print()

est_inv_hess = np.linalg.inv(est_hess)
est_inv_zeroth_hess = np.linalg.inv(est_zeroth_hess)
true_inv_hess = np.linalg.inv(true_hess)
print(np.linalg.norm(est_inv_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
print(np.linalg.norm(est_inv_zeroth_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
# Out:
# [  31.913883   175.863       89.604095    11.8570595  186.98074
#   128.23706   -174.49368   -510.35654     28.890701   130.29907  ]
# zeroth [ 11.995098   24.652576   13.256062   11.762185   16.296373   18.034893
#   -3.1481867 -49.7265      9.850971   10.065311 ]
# true [7.368863  4.6579976 4.8862576 6.5293922 7.9989076 3.5752895 7.261648
#  3.3431666 5.728974  7.263932 ]
#
# 0.025539976
# 0.9969775

# %%
xs[0] = 0

true_hess = F.f2(np.array([xs]))
est_hess = dfe.new_beta_second_shift_estimator(F, xs, 5, 1000, jrandom_key) # 
est_zeroth_hess = dfe.beta_second_shift_estimator(F, xs, 1000, 1000, jrandom_key)
print(np.diag(est_zeroth_hess))
est_zeroth_hess = dfe.beta_second_shift_estimator(F, xs, 10, 1000, jrandom_key)

idx = 7
print("zeroth", jnp.diag(est_zeroth_hess))
# print("first", est_hess)
print("true", jnp.diag(true_hess[0]))
print()

est_inv_hess = np.linalg.inv(est_hess)
est_inv_zeroth_hess = np.linalg.inv(est_zeroth_hess)
true_inv_hess = np.linalg.inv(true_hess)
print(np.linalg.norm(est_inv_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
print(np.linalg.norm(est_inv_zeroth_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
# Out:
# [  31.913883   175.863       89.604095    11.8570595  186.98074
#   128.23706   -174.49368   -510.35654     28.890701   130.29907  ]
# zeroth [ 11.995098   24.652576   13.256062   11.762185   16.296373   18.034893
#   -3.1481867 -49.7265      9.850971   10.065311 ]
# true [7.368863  4.6579976 4.8862576 6.5293922 7.9989076 3.5752895 7.261648
#  3.3431666 5.728974  7.263932 ]
#
# 0.025539976
# 0.9969775

# %%
errs = []
errs_true = []
errs_zeroth = []
errs_fd = []
a = []
b = []
xs = np.ones(dim) / np.linalg.norm(np.ones(dim))
num_steps = 100
delta = 10
int_start, int_end = -0.75, -0.6
vals = []
hess_vals = []
for x in np.linspace(int_start, int_end, num_steps):
# for x in range(int_start, int_end, num_steps):
#     print(x)
    xs[0] = x
    
    vals.append(F.f(np.array([xs])))
    
#     print(est_inv_hess)
#.  get_neystrom_inv(combined_F.f2(X)[0], 50, subkey)

#     est_inv_hess = dfe.multilevel_inv_estimator(F, x_0, 200, 1000, a, jrandom_key) # dfe.new_beta_second_shift_estimator(F, x_0, 200, 2500, control_variate=True)

#     est_inv_hess = test_multilevel(F, x_0, 200, 1000, a, jrandom_key)
    
    
    true_hess = F.f2(np.array([xs]))
    est_hess = dfe.new_beta_second_shift_estimator(F, xs, 100, 1000, jrandom_key) # 
    est_zeroth_hess = dfe.beta_second_shift_estimator(F, xs, 10000, 10000, jrandom_key)
#     fd_hess = finite_difference_hessian(F, jnp.array([xs]), 0.001)
#     print(est_zeroth_hess)
#     print(true_hess)
#     print()
#     hess_vals.append(jnp.linalg.norm(true_hess.reshape(-1)))
    # #     true_projected_inv_hess = np.array([dfe.get_neystrom_inv(true_hess[0], a, jrandom_key)])

    est_inv_hess = np.linalg.inv(est_hess)
    est_inv_zeroth_hess = np.linalg.inv(est_zeroth_hess)
    true_inv_hess = np.linalg.inv(true_hess)
    fd_inv_hess = jnp.linalg.inv(fd_hess)
    errs_fd.append(np.linalg.norm(fd_inv_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
    errs.append(np.linalg.norm(est_inv_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
    errs_zeroth.append(np.linalg.norm(est_inv_zeroth_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
    
#     errs_true.append(np.linalg.norm(true_projected_inv_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
#     errs.append(np.linalg.norm(est_hess - true_hess)/np.linalg.norm(true_hess))

# %%
plt.plot(np.linspace(int_start, int_end, num_steps), vals)
plt.show()

# plt.plot(np.linspace(int_start, int_end, num_steps), hess_vals)
# plt.show()

plt.plot(np.linspace(int_start, int_end, num_steps), errs, label="first")
plt.plot(np.linspace(int_start, int_end, num_steps), errs_zeroth, label="zeroth")
# plt.plot(np.linspace(int_start, int_end, num_steps), errs_fd, label="Finite Difference")
plt.legend()

# plt.ylim(0, 1)

plt.show()

# %%
x_0 =   newton_path[0][-15][0][0]

est_hess = dfe.new_beta_second_shift_estimator(combined_F, x_0, 2000000, 5000)
true_hess = combined_F.f2(np.array([x_0]))
print("relative error", np.linalg.norm(est_hess - true_hess)/np.linalg.norm(true_hess))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9096dd7a8f84> in <module>
# ----> 1 x_0 =   newton_path[0][-15][0][0]
#       2
#       3 est_hess = dfe.new_beta_second_shift_estimator(combined_F, x_0, 2000000, 5000)
#       4 true_hess = combined_F.f2(np.array([x_0]))
#       5 print("relative error", np.linalg.norm(est_hess - true_hess)/np.linalg.norm(true_hess))
#
# NameError: name 'newton_path' is not defined

# %%
len(newton_path[0])
# Out:
# 290

# %%
errs = []
num_steps = 20
vals = []
newton_decrement = []

bfgs_H = np.eye(dim)
# bfgs_err = []
for i in range(230, 289):
#     print(x)
    x_0 = newton_path[0][i][0][0]
    
    vals.append(combined_F.f(np.array([x_0])))
    
    est_hess = dfe.new_beta_second_shift_estimator(combined_F, x_0, 2000, 2500, control_variate=True)
    true_hess = combined_F.f2(np.array([x_0]))
    
    est_inv_hess = np.linalg.inv(est_hess)
    true_inv_hess = np.linalg.inv(true_hess)
    
    est_newton = np.inner(est_inv_hess, combined_F.f1(np.array([x_0]))[0])
    true_newton = np.dot(true_inv_hess,combined_F.f1(np.array([x_0]))[0])
    
    newton_decrement.append(np.dot(combined_F.f1(np.array([x_0]))[0], est_newton))

    errs.append(np.linalg.norm(est_inv_hess - true_inv_hess)/np.linalg.norm(true_inv_hess))
#     errs.append(np.linalg.norm(est_hess - true_hess)/np.linalg.norm(true_hess))
#     errs.append(np.linalg.norm(est_newton - true_newton)/np.linalg.norm(true_newton))
#     bfgs_err.append(np.linalg.norm(bfgs_H - true_inv_hess)/np.linalg.norm(true_inv_hess))
    
#     bfgs_H = dfe.BFGS_update(combined_F, newton_path[0][i+1][0][0], newton_path[0][i][0][0], bfgs_H)


plt.plot(vals)
plt.show()

plt.plot(errs)
plt.show()

plt.plot(bfgs_err)
plt.show()

plt.plot(newton_decrement)
plt.show()

# %%
min(newton_decrement)
# Out:
# -318.97809540470973

# %%
 as newton decrement smaller more samples
    if negative newton decrement, reuse samples? 
higher rank perturbation

# %%
exp_path = "/Users/daniellengyel/new_adventure/experiments/linear/"

newton_folder = "Newton_IPM_Apr17_16-44-53_Daniels-MacBook-Pro-4.local"
newton_id = "1618674293.851346"
newton_path = na.save_load.load_opt_path(exp_path + newton_folder, newton_id)

# %%
last_p = newton_path[-1][-1]

# %%
time_step = 0
t = 4 * (0.5)**(time_step) # (1.5)**(time_step)

np.random.seed(10)
dim = 750
num_barriers = dim * 2
dirs = np.random.normal(size=(num_barriers, dim)) # sample gaussian and normalize 
ws = dirs/np.linalg.norm(dirs, axis=1).reshape(-1, 1)
bs = np.ones(num_barriers)
c = np.ones(dim)
F = na.Functions.Linear(c)
barrier = na.Barriers.LogPolytopeBarrier(ws, bs)
combined_F = na.Functions.LinearCombination(F, barrier, [1, t])

# %%
combined_F.f(last_p[0])
# Out:
# array([inf])

# %%
estimated_times = []
true_times = []

# %%
for dim in range(100, 500, 25):
    xs = np.zeros(dim)

    print(dim)
    np.random.seed(10)
#     dim = 1000
    num_barriers = dim * 2
    dirs = np.random.normal(size=(num_barriers, dim)) # sample gaussian and normalize 
    ws = dirs/np.linalg.norm(dirs, axis=1).reshape(-1, 1)
    bs = np.ones(num_barriers)


    # num_barriers = 6
    # dim = 3
    # dirs = np.random.normal(size=(num_barriers, dim)) # sample gaussian and normalize 
    # ws = dirs/np.linalg.norm(dirs, axis=1).reshape(-1, 1)
    # bs = np.ones(num_barriers)
    barrier = na.Barriers.LogPolytopeBarrier(ws, bs)

    F = na.Functions.Linear(np.ones(dim))

    F = na.Functions.LinearCombination(F, barrier, [1, 1])

    a = time.time()
    true_hess = F.f2(np.array([xs]))
    true_times.append(time.time() - a)
    
    a = time.time()

    est_hess = dfe.new_beta_second_shift_estimator(barrier, xs, 500, 500, control_variate=True, estimated_gradient=True)
    estimated_times.append(time.time() - a)
# Out:
# 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-392-bdcae6d4db62> in <module>
#      24     a = time.time()
#      25     true_hess = F.f2(np.array([xs]))
# ---> 26     true_times.append(time.time() - a)
#      27
#      28     a = time.time()
#
# NameError: name 'true_times' is not defined

# %%
plt.plot(true_times, label="true")
plt.plot(estimated_times, label="estimated")
plt.legend()

# %%
a = time.time()

est_hess = dfe.new_beta_second_shift_estimator(barrier, xs, 500, 500, control_variate=True)
print(time.time() - a)
# Out:
# 2.549027919769287

# %%
est_hess = dfe.new_beta_second_shift_estimator(barrier, xs, 500, 500, control_variate=True, estimated_gradient=False)
true_hess = F.f2(np.array([xs]))


est_inv_hess = np.linalg.inv(est_hess)
true_inv_hess = np.linalg.inv(true_hess)
np.linalg.norm(est_inv_hess - true_inv_hess)/np.linalg.norm(true_inv_hess)
# Out:
# 0.0694878863900093

# %% [markdown]
# # Plot Barrier

# %%
np.random.seed(10)
num_barriers = 4
dim = 2
dirs = np.random.normal(size=(num_barriers, dim)) # sample gaussian and normalize 
ws = dirs/np.linalg.norm(dirs, axis=1).reshape(-1, 1)
bs = np.ones(num_barriers)
barrier = na.Barriers.LogPolytopeBarrier(ws, bs)

# %%
figure_size = (14, 10)
fig = plt.figure(figsize=figure_size)
ax = fig.add_subplot(1, 1, 1)
na.animations.draw_polytope(barrier.ws, barrier.bs, 5, ax)
# ax.scatter(ys[:, 0], ys[:, 1])
# plt.xlim(-0.6, 0.6)
# plt.ylim(-0.6, 0.6)

# for i in range(len(dirs)):
#     ax.plot([xs[0][0], xs[0][0] + min(dists[i]) * dirs[i][0]], [xs[0][1], xs[0][1] + min(dists[i]) * dirs[i][1]])

# %% [markdown]
# # We are gonna make BFGS happen YOOOOOO

# %%
signs = np.array([[1, 1, -1], [1, 1, 1]])
dists
# Out:
# /Users/daniellengyel/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply
# array([inf, nan])

# %%
np.random.seed(10)
dim = 1500
num_barriers = dim * 2
dirs = np.random.normal(size=(num_barriers, dim)) # sample gaussian and normalize 
ws = dirs/np.linalg.norm(dirs, axis=1).reshape(-1, 1)
bs = np.ones(num_barriers)
c = np.ones(dim)
time_step = 1
t = 4 * (0.5)**(time_step) # (1.5)**(time_step)
F = na.Functions.Linear(c)
barrier = na.Barriers.LogPolytopeBarrier(ws, bs)
combined_F = na.Functions.LinearCombination(F, barrier, [1, t])

# %%
barrier = na.Barriers.LogPolytopeBarrier(ws, bs)

# %%
x_0 = np.zeros(dim)
N = 1000
alpha = 1000
t_dict = {}
for n in range(10, 10000, 100):
    if n not in t_dict:
        t_dict[n] = []
    for alpha in range(2000, 2010, 100):
        
        a = time.time()
        # C = dfe.new_beta_inverse_second_shift_estimator(barrier, x_0, alpha, N, control_variate=True, estimated_gradient=False)
        # print(time.time() - a)
        # a = time.time()
        D = np.linalg.inv(dfe.new_beta_second_shift_estimator(barrier, x_0, 50, n, control_variate=True, estimated_gradient=False))
        # print(time.time() - a)
        t_dict[n].append(time.time() - a)
        print(n)
        print("Total time", time.time() - a)
        # combined_F.barrier.f1(np.array([x_0, np.ones(dim)]))
# Out:
# 10
# Total time 0.0375211238861084
# 110
# Total time 0.03807401657104492
# 210
# Total time 0.04396390914916992
# 310
# Total time 0.03896975517272949
# 410
# Total time 0.0508112907409668
# 510
# Total time 0.06409430503845215
# 610
# Total time 0.07095122337341309
# 710
# Total time 0.06670904159545898
# 810
# Total time 0.09652185440063477
# 910
# Total time 0.11629700660705566
# 1010
# Total time 0.09433698654174805
# 1110
# Total time 0.09781312942504883
# 1210
# Total time 0.10876011848449707
# 1310
# Total time 0.1346299648284912
# 1410
# Total time 0.12905287742614746
# 1510
# Total time 0.15863990783691406
# 1610
# Total time 0.16060805320739746
# 1710
# Total time 0.14589691162109375
# 1810
# Total time 0.18148207664489746
# 1910
# Total time 0.198394775390625
# 2010
# Total time 0.23066496849060059
# 2110
# Total time 0.1968989372253418
# 2210
# Total time 0.19778776168823242
# 2310
# Total time 0.18946599960327148
# 2410
# Total time 0.1891930103302002
# 2510
# ...

# %%
x_0 = np.zeros(dim)
N = 1000
alpha = 1000

        
a = time.time()
C = dfe.new_beta_inverse_second_shift_estimator(barrier, x_0, alpha, 10000, control_variate=True, estimated_gradient=False)
print(time.time() - a)
# a = time.time()
# D = np.linalg.inv(dfe.new_beta_second_shift_estimator(barrier, x_0, alpha, 10000, control_variate=True, estimated_gradient=False))
# print(time.time() - a)
# t_dict[n].append(time.time() - a)
# print(n)
print("Total time", time.time() - a)
# combined_F.barrier.f1(np.array([x_0, np.ones(dim)]))
# Out:
# sampling points 1.4086458683013916
# Get grads 0.7436699867248535
# Get second shift est 0.1428983211517334
# get sample cov 0.09506988525390625
# get second inverse 0.024730920791625977
# 2.4432709217071533
# Total time 2.4433979988098145

# %%
x_0 = np.zeros(dim)
N = 1000
alpha = 1000

        
a = time.time()
combined_F.f2_inv(np.array([x_0]))
# C = dfe.new_beta_inverse_second_shift_estimator(barrier, x_0, alpha, 10000, control_variate=True, estimated_gradient=False)
print(time.time() - a)
# a = time.time()
# D = np.linalg.inv(dfe.new_beta_second_shift_estimator(barrier, x_0, alpha, 10000, control_variate=True, estimated_gradient=False))
# print(time.time() - a)
# t_dict[n].append(time.time() - a)
# print(n)
print("Total time", time.time() - a)
# combined_F.barrier.f1(np.array([x_0, np.ones(dim)]))
# Out:
# 0.26926279067993164
# Total time 0.26940178871154785

# %%
a = time.time()
C = barrier.f2_inv(np.array([x_0]))
print("Total time", time.time() - a)
# Out:
# Total time 0.01896977424621582

# %%
plt.plot(list(t_dict.values()))

# %%
ord('c') - ord('a')
# Out:
# 2

# %%
len(s)
# Out:
# 90
