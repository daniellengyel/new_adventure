# %%
import jax.numpy as jnp
from jax import random as jrandom
import matplotlib.pyplot as plt
import new_adventure as na

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
plt.rcParams['figure.figsize'] = [16,8]
plt.style.use('ggplot')
plt.rcParams['lines.markersize'] = 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
domain = [-10, 10]

# class Tesselated:
#     def __init__(self, func, N, domain, jrandom_key):
#         self.func = func
#         self.N = N
#         self.domain = domain
#         self.jrandom_key = jrandom_key
#         self.jrandom_key, subkey = jrandom.split(self.jrandom_key)
#         S = jrandom.uniform(subkey, shape=(self.N, domain["dim"]), minval=domain["bound"][0], maxval=domain["bound"][1])
#         self.m = func.f1(S)
#         self.b = func.f(S) - jnp.sum(self.m * S, axis=1) # we have y = f + grad (x - x_0) = f - grad x_0 + grad x
                    
#     def f(self, X):
#         return jnp.max(self.b + X.dot(self.m.T), axis=1)
    
#     def f_all(self, X):
#         """For ploting:
#         out_all = t.f_all(X)
#         for x in out_all.T:
#             plt.scatter(X, x)"""
#         return self.b + X.dot(self.m.T)

domain = {"dim": , "bound": [-100, 100]}
jrandom_key = jrandom.PRNGKey(0)
jrandom_key, subkey = jrandom.split(jrandom_key)

t = na.Functions.Tesselated(na.Functions.Quadratic(jnp.eye(domain["dim"]), jnp.zeros(domain["dim"])), 10, domain, subkey)

jrandom_key, subkey = jrandom.split(jrandom_key)
X = jrandom.uniform(subkey, shape=(1000, domain["dim"]), minval=domain["bound"][0], maxval=domain["bound"][1])
out = t.f(X)
plt.scatter(X, out)
# out_all = t.f_all(X)
# for x in out_all.T:
#     plt.scatter(X, x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-e8384ba84ab9> in <module>
#      26 jrandom_key, subkey = jrandom.split(jrandom_key)
#      27
# ---> 28 t = na.Functions.Tesselated(na.Functions.Quadratic(jnp.eye(domain["dim"]), jnp.zeros(domain["dim"])), 10, domain, subkey)
#      29
#      30 jrandom_key, subkey = jrandom.split(jrandom_key)
#
# ~/new_adventure/new_adventure/Functions.py in __init__(self, func, N, domain, jrandom_key)
#     230         S = jrandom.uniform(jrandom_key, shape=(self.N, domain["dim"]), minval=domain["bound"][0], maxval=domain["bound"][1])
#     231         self.m = func.f1(S)
# --> 232         self.b = func.f(S) - jnp.sum(self.m * S, axis=1) # we have y = f + grad (x - x_0) = f - grad x_0 + grad x
#     233
#     234     def f(self, X):
#
# ~/new_adventure/new_adventure/Functions.py in f(self, X)
#      21     def f(self, X):
#      22         Y = np.dot(self.Q, X.T)
# ---> 23         Y = jnp.diag(jnp.dot(X, Y)) + self.b.dot(X) # TODO fix. inefficient way to remove x_j^T Q x_i for i != j.
#      24         return Y
#      25
#
# ~/miniconda3/lib/python3.6/site-packages/jax/_src/numpy/lax_numpy.py in dot(a, b, precision)
#    4016     return lax.mul(a, b)
#    4017   if _max(a_ndim, b_ndim) <= 2:
# -> 4018     return lax.dot(a, b, precision=precision)
#    4019
#    4020   if b_ndim == 1:
#
# ~/miniconda3/lib/python3.6/site-packages/jax/_src/lax/lax.py in dot(lhs, rhs, precision, preferred_element_type)
#     662   else:
#     663     raise TypeError("Incompatible shapes for dot: got {} and {}.".format(
# --> 664         lhs.shape, rhs.shape))
#     665
#     666
#
# TypeError: Incompatible shapes for dot: got (2,) and (10, 2).

# %%
g = GaussianSmoothing(t, jrandom_key, 10000, 50)
X = jrandom.uniform(subkey, shape=(1000, domain["dim"]), minval=domain["bound"][0], maxval=domain["bound"][1])
out = g.f(X)
plt.scatter(X, out)

# %%
a.T
# Out:
# DeviceArray([[ 5.769489 ,  6.974745 , -4.164431 ,  2.4043775, -9.14957  ,
#               -2.0068312, -3.9542031,  6.4731216, -8.933952 ,  8.003977 ]],            dtype=float32)

# %%
out = g.f1(X)

# %%
plt.scatter(X, out)

# %%
class GaussianSmoothing:
    def __init__(self, func, jrandom_key, N, sigma):
        self.func = func
        self.jrandom_key = jrandom_key
        self.N = N
        self.sigma = sigma
    
    def f(self, X):
        d = X.shape[1]
        cov = self.sigma**2*jnp.eye(d)
        self.jrandom_key, subkey = jrandom.split(self.jrandom_key)
        x_samples = jrandom.multivariate_normal(key=subkey, mean=X, cov=cov, shape=(self.N, len(X), )).transpose(1, 0, 2)
        f_out = self.func.f(x_samples.reshape(-1, d)).reshape(len(X), self.N)
        return jnp.mean(f_out, axis=1)
        
    def f1(self, X):
        d = X.shape[1]
        cov = self.sigma**2*jnp.eye(d)
        self.jrandom_key, subkey = jrandom.split(self.jrandom_key)
        x_samples = jrandom.multivariate_normal(key=subkey, mean=X, cov=cov, shape=(self.N, len(X), )).transpose(1, 0, 2)
        
        f_out = self.func.f(x_samples.reshape(-1, d)).reshape(len(X), self.N)
        
        res = []
        for i in range(len(X)):
            res.append((x_samples[i] - jnp.mean(x_samples[i])).T.dot(f_out[i]) / self.N) 
        res = jnp.array(res)
        return jnp.linalg.inv(cov).dot(res.T)
    
    def f2(self, X):
        d = X.shape[1]
        cov = self.sigma**2*jnp.eye(d)
        self.jrandom_key, subkey = jrandom.split(self.jrandom_key)
        x_samples = jrandom.multivariate_normal(key=subkey, mean=X, cov=cov, shape=(self.N, len(X), )).transpose(1, 0, 2)
        
        f_out = self.func.f(x_samples.reshape(-1, d)).reshape(len(X), self.N)
        
        res = []
        for i in range(len(X)):
            x_diff = x_samples[i] - jnp.mean(x_samples[i]) # N, d
            cov_inv = jnp.linalg.inv(x_diff.T.dot(x_diff) / self.N)

            res.append( (cov_inv.dot(x_diff.T * f_out[i]).dot(x_diff).dot(cov_inv) - cov_inv * jnp.sum(f_out[i]) ) / self.N) 
        res = jnp.array(res)
        return res

# %%
g = GaussianSmoothing(t, jrandom_key, 50000, 1)
X = jrandom.uniform(subkey, shape=(50, domain["dim"]), minval=domain["bound"][0], maxval=domain["bound"][1])

out = g.f2(X)
plt.scatter(X, out)

# %%
jrandom_key, subkey = jrandom.split(jrandom_key)
N  = 10000
sigma = 10 
x_samples = jrandom.multivariate_normal(key=subkey, mean=jnp.array([20]), cov=sigma**2 * jnp.array([[1]]), shape=(N, ))#.reshape(-1)

f_out = 100 * x_samples

x_diff = x_samples - jnp.mean(x_samples)
cov_inv = jnp.linalg.inv(x_diff.T.dot(x_diff) / N)
print(cov_inv)
print(jnp.mean(x_samples))

print(cov_inv[0][0] * (x_diff.T * f_out.reshape(-1)).dot(x_diff).dot(cov_inv))
print(cov_inv * jnp.sum(f_out))
print(jnp.mean(f_out))
print(cov_inv)

( (x_diff.T * f_out.reshape(-1)).dot(x_diff).dot(cov_inv) - jnp.sum(f_out) ) / (sigma**2 * N )
# Out:
# [[0.010136]]
# 19.981207
# [[203567.97]]
# [[202529.64]]
# 1998.1215
# [[0.010136]]
# DeviceArray([[0.10244]], dtype=float32)

# %%
plt.plot(x_samples, f_out)

# %% [markdown]
# We have $\int f(x) \Sigma^{-1} (x - x_0) e^{ - (x - x_0)^T \Sigma^{-1} (x - x_0) / 2} dx $. Now the second derivative is:
# $\int f(x) \Sigma^{-1} (-1)  e^{ - (x - x_0)^T \Sigma^{-1} (x - x_0) / 2} + f(x)\Sigma^{-1} (x - x_0)(x - x_0)^T \Sigma^{-1}  e^{ - (x - x_0)^T \Sigma^{-1} (x - x_0) / 2} dx$

# %%
bounds = [-10, 10]
num_samples = 100

X = jnp.linspace(bounds[0], bounds[1], num_samples)
XY = jnp.array(jnp.meshgrid(X, X)).T.reshape(-1, 2) # .reshape(-1, 2)
print(XY.shape)

jrandom_key = jrandom.PRNGKey(0)
sigma = 1
smoothing = na.Functions.GaussianSmoothing(na.Functions.MAXQ(), 5000, sigma)


out = smoothing.f(XY, jrandom_key, sigma ).reshape(num_samples, num_samples, )
# Out:
# (10000, 2)

# %%
import plotly.graph_objects as go


fig = go.Figure(data=[go.Surface(x=X, y=X, z=out,)]) #Surface

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()
# Out:
# <div>                            <div id="6bce8b0a-10b0-425e-9e3c-482cfc09ee53" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bce8b0a-10b0-425e-9e3c-482cfc09ee53")) {                    Plotly.newPlot(                        "6bce8b0a-10b0-425e-9e3c-482cfc09ee53",                        [{"type": "surface", "x": [-10.0, -9.797979354858398, -9.595958709716797, -9.393939971923828, -9.191919326782227, -8.989898681640625, -8.787878036499023, -8.585858345031738, -8.383838653564453, -8.181818008422852, -7.979797840118408, -7.777778148651123, -7.57575798034668, -7.373737335205078, -7.171716690063477, -6.96969747543335, -6.767677307128906, -6.565656661987305, -6.363636016845703, -6.16161584854126, -5.959596633911133, -5.757575035095215, -5.55555534362793, -5.3535356521606445, -5.151515007019043, -4.949495315551758, -4.747474670410156, -4.545454978942871, -4.3434343338012695, -4.141414642333984, -3.939393997192383, -3.7373735904693604, -3.5353541374206543, -3.3333325386047363, -3.1313133239746094, -2.929292678833008, -2.7272722721099854, -2.5252530574798584, -2.3232319355010986, -2.1212120056152344, -1.9191923141479492, -1.7171716690063477, -1